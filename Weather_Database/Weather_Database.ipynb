# %%
# Dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from config import g_key
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

# %%
coords = list(zip(lats,lngs))

# Create a cities list.
cities = []

# Get the nearest city using the citypy module.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 764

# %%
# Base Url.
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the city weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of the Set 1 | kontokalion
# Processing Record 3 of the Set 1 | euclides da cunha
# Processing Record 4 of the Set 1 | yellowknife
# Processing Record 5 of the Set 1 | dalnegorsk
# City not found. Skipping...
# Processing Record 6 of the Set 1 | kochevo
# City not found. Skipping...
# Processing Record 7 of the Set 1 | mataura
# Processing Record 8 of the Set 1 | albany
# Processing Record 9 of the Set 1 | khatanga
# City not found. Skipping...
# Processing Record 10 of the Set 1 | victor harbor
# Processing Record 11 of the Set 1 | carnarvon
# Processing Record 12 of the Set 1 | terlizzi
# Processing Record 13 of the Set 1 | nanyamba
# Processing Record 14 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of the Set 1 | meiktila
# Processing Record 16 of the Set 1 | suzhou
# Processing Record 17 of the Set 1 | tura
# City not found. Skipping...
# Processing Record 18 of the Set 1 | college
# Processing Record 19 of the Set 1 | bethel
# Processing Record 20 of the Set 1 | saryozek
# Processing Record 21 of the Set 1 | harper
# Processing Record 22 of the Set 1 | urumqi
# Processing Record 23 of the Set 1 | cherskiy
# City not found. Skipping...
# Processing Record 24 of the Set 1 | clyde river
# Processing Record 25 of the Set 1 | rawson
# Processing Record 26 of the Set 1 | broome
# Processing Record 27 of the Set 1 | muravlenko
# City not found. Skipping...
# Processing Record 28 of the Set 1 | loikaw
# Processing Record 29 of the Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of the Set 1 | rikitea
# Processing Record 31 of the Set 1 | kharan
# Processing Record 32 of the Set 1 | karratha
# Processing Record 33 of the Set 1 | vaini
# Processing Record 34 of the Set 1 | gallup
# Processing Record 35 of the Set 1 | bredasdorp
# Processing Record 36 of the Set 1 | jodhpur
# Processing Record 37 of the Set 1 | alekseyevsk
# City not found. Skipping...
# Processing Record 38 of the Set 1 | izamal
# Processing Record 39 of the Set 1 | ushuaia
# Processing Record 40 of the Set 1 | kahului
# Processing Record 41 of the Set 1 | leh
# Processing Record 42 of the Set 1 | majene
# Processing Record 43 of the Set 1 | berlevag
# Processing Record 44 of the Set 1 | hithadhoo
# Processing Record 45 of the Set 1 | palmer
# Processing Record 46 of the Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of the Set 1 | ketchikan
# Processing Record 48 of the Set 1 | ilhabela
# Processing Record 49 of the Set 1 | trinidad
# Processing Record 50 of the Set 1 | roros
# Processing Record 1 of the Set 2 | ippy
# Processing Record 2 of the Set 2 | cape town
# Processing Record 3 of the Set 2 | hambantota
# Processing Record 4 of the Set 2 | narsaq
# Processing Record 5 of the Set 2 | filingue
# Processing Record 6 of the Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 7 of the Set 2 | busselton
# Processing Record 8 of the Set 2 | atuona
# Processing Record 9 of the Set 2 | bronnoysund
# Processing Record 10 of the Set 2 | hilo
# Processing Record 11 of the Set 2 | ferme-neuve
# Processing Record 12 of the Set 2 | kapaa
# Processing Record 13 of the Set 2 | punta arenas
# Processing Record 14 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of the Set 2 | hermanus
# Processing Record 16 of the Set 2 | norman wells
# Processing Record 17 of the Set 2 | kindia
# Processing Record 18 of the Set 2 | lang son
# Processing Record 19 of the Set 2 | cidreira
# Processing Record 20 of the Set 2 | chandbali
# Processing Record 21 of the Set 2 | maneadero
# Processing Record 22 of the Set 2 | sinnamary
# Processing Record 23 of the Set 2 | lasa
# Processing Record 24 of the Set 2 | avarua
# Processing Record 25 of the Set 2 | dikson
# City not found. Skipping...
# Processing Record 26 of the Set 2 | vitim
# City not found. Skipping...
# Processing Record 27 of the Set 2 | lagoa
# Processing Record 28 of the Set 2 | gashua
# Processing Record 29 of the Set 2 | cap malheureux
# Processing Record 30 of the Set 2 | stryn
# Processing Record 31 of the Set 2 | sao filipe
# Processing Record 32 of the Set 2 | saldanha
# Processing Record 33 of the Set 2 | tuktoyaktuk
# Processing Record 34 of the Set 2 | ribeira grande
# Processing Record 35 of the Set 2 | seoul
# Processing Record 36 of the Set 2 | bilma
# Processing Record 37 of the Set 2 | skjervoy
# Processing Record 38 of the Set 2 | arraial do cabo
# Processing Record 39 of the Set 2 | bilibino
# City not found. Skipping...
# Processing Record 40 of the Set 2 | belyy yar
# City not found. Skipping...
# Processing Record 41 of the Set 2 | hobart
# Processing Record 42 of the Set 2 | houma
# Processing Record 43 of the Set 2 | nioro
# Processing Record 44 of the Set 2 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 45 of the Set 2 | kandrian
# Processing Record 46 of the Set 2 | guanica
# Processing Record 47 of the Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 48 of the Set 2 | illoqqortoormiut
# Processing Record 49 of the Set 2 | castro
# Processing Record 50 of the Set 2 | raudeberg
# Processing Record 1 of the Set 3 | jamestown
# Processing Record 2 of the Set 3 | prince rupert
# Processing Record 3 of the Set 3 | puerto ayora
# Processing Record 4 of the Set 3 | faanui
# Processing Record 5 of the Set 3 | geraldton
# Processing Record 6 of the Set 3 | saskylakh
# City not found. Skipping...
# Processing Record 7 of the Set 3 | butaritari
# Processing Record 8 of the Set 3 | panorama
# Processing Record 9 of the Set 3 | brae
# Processing Record 10 of the Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 11 of the Set 3 | mosesgegh
# Processing Record 12 of the Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 13 of the Set 3 | tuatapere
# Processing Record 14 of the Set 3 | lompoc
# Processing Record 15 of the Set 3 | kodiak
# Processing Record 16 of the Set 3 | manassas
# Processing Record 17 of the Set 3 | jurilovca
# Processing Record 18 of the Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of the Set 3 | chernaya kholunitsa
# City not found. Skipping...
# Processing Record 20 of the Set 3 | upernavik
# Processing Record 21 of the Set 3 | mar del plata
# Processing Record 22 of the Set 3 | jaru
# Processing Record 23 of the Set 3 | diego de almagro
# Processing Record 24 of the Set 3 | kaitangata
# Processing Record 25 of the Set 3 | waingapu
# Processing Record 26 of the Set 3 | devils lake
# Processing Record 27 of the Set 3 | rocha
# Processing Record 28 of the Set 3 | khandagayty
# City not found. Skipping...
# Processing Record 29 of the Set 3 | tessalit
# Processing Record 30 of the Set 3 | nishihara
# Processing Record 31 of the Set 3 | bluff
# Processing Record 32 of the Set 3 | vryburg
# Processing Record 33 of the Set 3 | qaanaaq
# Processing Record 34 of the Set 3 | chilakalurupet
# Processing Record 35 of the Set 3 | goderich
# Processing Record 36 of the Set 3 | hasaki
# Processing Record 37 of the Set 3 | new norfolk
# Processing Record 38 of the Set 3 | bengkulu
# Processing Record 39 of the Set 3 | tasiilaq
# Processing Record 40 of the Set 3 | dingle
# Processing Record 41 of the Set 3 | kungurtug
# City not found. Skipping...
# Processing Record 42 of the Set 3 | constitucion
# Processing Record 43 of the Set 3 | severo-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of the Set 3 | promyshlennovskiy
# City not found. Skipping...
# Processing Record 45 of the Set 3 | ahipara
# Processing Record 46 of the Set 3 | lively
# Processing Record 47 of the Set 3 | namtsy
# City not found. Skipping...
# Processing Record 48 of the Set 3 | cartama
# Processing Record 49 of the Set 3 | aykhal
# City not found. Skipping...
# Processing Record 50 of the Set 3 | saint-philippe
# Processing Record 1 of the Set 4 | delvada
# Processing Record 2 of the Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of the Set 4 | meulaboh
# Processing Record 4 of the Set 4 | severo-kurilsk
# City not found. Skipping...
# Processing Record 5 of the Set 4 | louisbourg
# Processing Record 6 of the Set 4 | tanshui
# City not found. Skipping...
# Processing Record 7 of the Set 4 | mount gambier
# Processing Record 8 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of the Set 4 | ponta do sol
# Processing Record 10 of the Set 4 | beringovskiy
# City not found. Skipping...
# Processing Record 11 of the Set 4 | lerwick
# Processing Record 12 of the Set 4 | russkaya polyana
# City not found. Skipping...
# Processing Record 13 of the Set 4 | dwarka
# Processing Record 14 of the Set 4 | bac lieu
# Processing Record 15 of the Set 4 | mashivka
# Processing Record 16 of the Set 4 | port alfred
# Processing Record 17 of the Set 4 | sao joao da barra
# Processing Record 18 of the Set 4 | kamaishi
# Processing Record 19 of the Set 4 | panacan
# Processing Record 20 of the Set 4 | zhigansk
# City not found. Skipping...
# Processing Record 21 of the Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of the Set 4 | barrow
# Processing Record 23 of the Set 4 | tucuman
# Processing Record 24 of the Set 4 | mahebourg
# Processing Record 25 of the Set 4 | smolenskoye
# City not found. Skipping...
# Processing Record 26 of the Set 4 | kloulklubed
# Processing Record 27 of the Set 4 | inta
# City not found. Skipping...
# Processing Record 28 of the Set 4 | palabuhanratu
# Processing Record 29 of the Set 4 | mayya
# City not found. Skipping...
# Processing Record 30 of the Set 4 | marignane
# Processing Record 31 of the Set 4 | troutdale
# Processing Record 32 of the Set 4 | ituni
# City not found. Skipping...
# Processing Record 33 of the Set 4 | aflu
# City not found. Skipping...
# Processing Record 34 of the Set 4 | sokolovo
# City not found. Skipping...
# Processing Record 35 of the Set 4 | cabo san lucas
# Processing Record 36 of the Set 4 | deputatskiy
# City not found. Skipping...
# Processing Record 37 of the Set 4 | pilar
# Processing Record 38 of the Set 4 | brewster
# Processing Record 39 of the Set 4 | warqla
# City not found. Skipping...
# Processing Record 40 of the Set 4 | tungor
# City not found. Skipping...
# Processing Record 41 of the Set 4 | kampong thum
# Processing Record 42 of the Set 4 | paradwip
# Processing Record 43 of the Set 4 | souillac
# Processing Record 44 of the Set 4 | esik
# Processing Record 45 of the Set 4 | los llanos de aridane
# Processing Record 46 of the Set 4 | high level
# Processing Record 47 of the Set 4 | necochea
# Processing Record 48 of the Set 4 | hohhot
# Processing Record 49 of the Set 4 | yumen
# Processing Record 50 of the Set 4 | luanda
# Processing Record 1 of the Set 5 | ler
# Processing Record 2 of the Set 5 | sao felix do xingu
# Processing Record 3 of the Set 5 | kamina
# Processing Record 4 of the Set 5 | roald
# Processing Record 5 of the Set 5 | la rioja
# Processing Record 6 of the Set 5 | chatra
# Processing Record 7 of the Set 5 | lavrentiya
# Processing Record 8 of the Set 5 | namibe
# Processing Record 9 of the Set 5 | tilichiki
# Processing Record 10 of the Set 5 | pisco
# Processing Record 11 of the Set 5 | batagay-alyta
# Processing Record 12 of the Set 5 | kruisfontein
# Processing Record 13 of the Set 5 | belushya guba
# Processing Record 14 of the Set 5 | hay river
# Processing Record 15 of the Set 5 | vanimo
# Processing Record 16 of the Set 5 | trofors
# Processing Record 17 of the Set 5 | cuajinicuilapa
# Processing Record 18 of the Set 5 | lebu
# Processing Record 19 of the Set 5 | soyo
# Processing Record 20 of the Set 5 | whitehorse
# Processing Record 21 of the Set 5 | victoria
# Processing Record 22 of the Set 5 | san rafael
# Processing Record 23 of the Set 5 | torbay
# Processing Record 24 of the Set 5 | coihaique
# Processing Record 25 of the Set 5 | dong xoai
# Processing Record 26 of the Set 5 | port elizabeth
# Processing Record 27 of the Set 5 | kalengwa
# Processing Record 28 of the Set 5 | rockland
# Processing Record 29 of the Set 5 | sandakan
# Processing Record 30 of the Set 5 | faranah
# Processing Record 31 of the Set 5 | chivilcoy
# Processing Record 32 of the Set 5 | saint-augustin
# Processing Record 33 of the Set 5 | bandarban
# Processing Record 34 of the Set 5 | tairua
# Processing Record 35 of the Set 5 | bila
# Processing Record 36 of the Set 5 | ponta delgada
# Processing Record 37 of the Set 5 | xiongzhou
# Processing Record 38 of the Set 5 | marsh harbour
# Processing Record 39 of the Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of the Set 5 | airai
# Processing Record 41 of the Set 5 | miraflores
# Processing Record 42 of the Set 5 | bjala
# City not found. Skipping...
# Processing Record 43 of the Set 5 | chute-aux-outardes
# Processing Record 44 of the Set 5 | pithapuram
# Processing Record 45 of the Set 5 | san patricio
# Processing Record 46 of the Set 5 | ancud
# Processing Record 47 of the Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of the Set 5 | coquimbo
# Processing Record 49 of the Set 5 | pevek
# Processing Record 50 of the Set 5 | kaseda
# Processing Record 1 of the Set 6 | trat
# Processing Record 2 of the Set 6 | aklavik
# Processing Record 3 of the Set 6 | saint george
# Processing Record 4 of the Set 6 | kathu
# Processing Record 5 of the Set 6 | fort nelson
# Processing Record 6 of the Set 6 | grand river south east
# Processing Record 7 of the Set 6 | grenfell
# Processing Record 8 of the Set 6 | aripuana
# Processing Record 9 of the Set 6 | pangnirtung
# Processing Record 10 of the Set 6 | talnakh
# Processing Record 11 of the Set 6 | virden
# Processing Record 12 of the Set 6 | kavieng
# Processing Record 13 of the Set 6 | thinadhoo
# Processing Record 14 of the Set 6 | codrington
# Processing Record 15 of the Set 6 | thompson
# Processing Record 16 of the Set 6 | kailua
# Processing Record 17 of the Set 6 | hyeres
# Processing Record 18 of the Set 6 | okmulgee
# Processing Record 19 of the Set 6 | port hardy
# Processing Record 20 of the Set 6 | omsukchan
# Processing Record 21 of the Set 6 | edd
# Processing Record 22 of the Set 6 | gainesville
# Processing Record 23 of the Set 6 | mareeba
# Processing Record 24 of the Set 6 | lorengau
# Processing Record 25 of the Set 6 | rauma
# Processing Record 26 of the Set 6 | mount pleasant
# Processing Record 27 of the Set 6 | ilulissat
# Processing Record 28 of the Set 6 | katsuura
# Processing Record 29 of the Set 6 | lemesos
# City not found. Skipping...
# Processing Record 30 of the Set 6 | kailaras
# Processing Record 31 of the Set 6 | hare bay
# Processing Record 32 of the Set 6 | kamwenge
# Processing Record 33 of the Set 6 | erzin
# Processing Record 34 of the Set 6 | grindavik
# City not found. Skipping...
# Processing Record 35 of the Set 6 | moose factory
# Processing Record 36 of the Set 6 | salalah
# Processing Record 37 of the Set 6 | andenes
# Processing Record 38 of the Set 6 | vestmanna
# Processing Record 39 of the Set 6 | tombouctou
# Processing Record 40 of the Set 6 | cururupu
# Processing Record 41 of the Set 6 | baykit
# Processing Record 42 of the Set 6 | baiyin
# Processing Record 43 of the Set 6 | vila franca do campo
# Processing Record 44 of the Set 6 | krasnyy chikoy
# Processing Record 45 of the Set 6 | asahi
# Processing Record 46 of the Set 6 | dhidhdhoo
# Processing Record 47 of the Set 6 | marmaris
# Processing Record 48 of the Set 6 | jumla
# Processing Record 49 of the Set 6 | bambous virieux
# Processing Record 50 of the Set 6 | bukama
# Processing Record 1 of the Set 7 | pacific grove
# Processing Record 2 of the Set 7 | gravdal
# Processing Record 3 of the Set 7 | nouadhibou
# Processing Record 4 of the Set 7 | boddam
# Processing Record 5 of the Set 7 | rungata
# Processing Record 6 of the Set 7 | methoni
# Processing Record 7 of the Set 7 | provideniya
# Processing Record 8 of the Set 7 | hirado
# Processing Record 9 of the Set 7 | weihai
# Processing Record 10 of the Set 7 | hauterive
# Processing Record 11 of the Set 7 | saint-pierre
# Processing Record 12 of the Set 7 | aksarka
# Processing Record 13 of the Set 7 | zapolyarnyy
# Processing Record 14 of the Set 7 | mogadishu
# City not found. Skipping...
# Processing Record 15 of the Set 7 | naze
# Processing Record 16 of the Set 7 | manaus
# Processing Record 17 of the Set 7 | elizabeth city
# Processing Record 18 of the Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 19 of the Set 7 | poum
# Processing Record 20 of the Set 7 | koumac
# Processing Record 21 of the Set 7 | vila velha
# Processing Record 22 of the Set 7 | half moon bay
# Processing Record 23 of the Set 7 | saleaula
# City not found. Skipping...
# Processing Record 24 of the Set 7 | tiznit
# Processing Record 25 of the Set 7 | angelholm
# City not found. Skipping...
# Processing Record 26 of the Set 7 | evensk
# Processing Record 27 of the Set 7 | hovd
# Processing Record 28 of the Set 7 | caravelas
# Processing Record 29 of the Set 7 | tiksi
# Processing Record 30 of the Set 7 | kathmandu
# Processing Record 31 of the Set 7 | salgueiro
# Processing Record 32 of the Set 7 | east london
# Processing Record 33 of the Set 7 | lima
# Processing Record 34 of the Set 7 | uruzgan
# Processing Record 35 of the Set 7 | nguiu
# Processing Record 36 of the Set 7 | nanortalik
# Processing Record 37 of the Set 7 | lithakia
# Processing Record 38 of the Set 7 | mitu
# Processing Record 39 of the Set 7 | port blair
# Processing Record 40 of the Set 7 | esperance
# Processing Record 41 of the Set 7 | komsomolskiy
# Processing Record 42 of the Set 7 | alegre
# Processing Record 43 of the Set 7 | chunoyar
# Processing Record 44 of the Set 7 | georgetown
# Processing Record 45 of the Set 7 | nabire
# Processing Record 46 of the Set 7 | batemans bay
# Processing Record 47 of the Set 7 | galiwinku
# Processing Record 48 of the Set 7 | mildura
# Processing Record 49 of the Set 7 | chuy
# Processing Record 50 of the Set 7 | firminy
# Processing Record 1 of the Set 8 | mandalgovi
# Processing Record 2 of the Set 8 | mabaruma
# City not found. Skipping...
# Processing Record 3 of the Set 8 | ouesso
# Processing Record 4 of the Set 8 | birin
# City not found. Skipping...
# Processing Record 5 of the Set 8 | sur
# Processing Record 6 of the Set 8 | capiata
# Processing Record 7 of the Set 8 | visby
# City not found. Skipping...
# Processing Record 8 of the Set 8 | kadykchan
# Processing Record 9 of the Set 8 | lata
# Processing Record 10 of the Set 8 | oistins
# Processing Record 11 of the Set 8 | bambanglipuro
# Processing Record 12 of the Set 8 | sangmelima
# Processing Record 13 of the Set 8 | flinders
# Processing Record 14 of the Set 8 | tazovskiy
# Processing Record 15 of the Set 8 | san quintin
# Processing Record 16 of the Set 8 | hirara
# Processing Record 17 of the Set 8 | taoudenni
# Processing Record 18 of the Set 8 | port keats
# Processing Record 19 of the Set 8 | acapulco
# Processing Record 20 of the Set 8 | noumea
# Processing Record 21 of the Set 8 | oranjemund
# Processing Record 22 of the Set 8 | wewak
# Processing Record 23 of the Set 8 | joshimath
# Processing Record 24 of the Set 8 | ianca
# Processing Record 25 of the Set 8 | dunedin
# Processing Record 26 of the Set 8 | kavaratti
# Processing Record 27 of the Set 8 | blackwater
# Processing Record 28 of the Set 8 | worland
# Processing Record 29 of the Set 8 | norton shores
# Processing Record 30 of the Set 8 | viligili
# Processing Record 31 of the Set 8 | sivaki
# Processing Record 32 of the Set 8 | blanquefort
# Processing Record 33 of the Set 8 | rurrenabaque
# Processing Record 34 of the Set 8 | toftir
# Processing Record 35 of the Set 8 | miri
# Processing Record 36 of the Set 8 | lannion
# Processing Record 37 of the Set 8 | attawapiskat
# Processing Record 38 of the Set 8 | kharp
# Processing Record 39 of the Set 8 | touros
# Processing Record 40 of the Set 8 | nome
# Processing Record 41 of the Set 8 | ust-ishim
# Processing Record 42 of the Set 8 | lodwar
# Processing Record 43 of the Set 8 | tabialan
# Processing Record 44 of the Set 8 | cedar city
# Processing Record 45 of the Set 8 | pingliang
# Processing Record 46 of the Set 8 | parrsboro
# Processing Record 47 of the Set 8 | sumbawa
# Processing Record 48 of the Set 8 | timmins
# Processing Record 49 of the Set 8 | puerto escondido
# Processing Record 50 of the Set 8 | mehamn
# Processing Record 1 of the Set 9 | chapais
# Processing Record 2 of the Set 9 | jinchang
# Processing Record 3 of the Set 9 | mayumba
# Processing Record 4 of the Set 9 | tahe
# Processing Record 5 of the Set 9 | manta
# Processing Record 6 of the Set 9 | hobyo
# City not found. Skipping...
# Processing Record 7 of the Set 9 | bethal
# Processing Record 8 of the Set 9 | dire
# Processing Record 9 of the Set 9 | fort frances
# Processing Record 10 of the Set 9 | broken hill
# Processing Record 11 of the Set 9 | buta
# Processing Record 12 of the Set 9 | vilhena
# Processing Record 13 of the Set 9 | el alto
# Processing Record 14 of the Set 9 | cheuskiny
# Processing Record 15 of the Set 9 | port-cartier
# Processing Record 16 of the Set 9 | bria
# Processing Record 17 of the Set 9 | chandpur
# Processing Record 18 of the Set 9 | yatou
# Processing Record 19 of the Set 9 | burns lake
# Processing Record 20 of the Set 9 | kununurra
# Processing Record 21 of the Set 9 | podgornoye
# Processing Record 22 of the Set 9 | alta
# Processing Record 23 of the Set 9 | baruun-urt
# Processing Record 24 of the Set 9 | tankhoy
# Processing Record 25 of the Set 9 | praid
# Processing Record 26 of the Set 9 | nagapattinam
# Processing Record 27 of the Set 9 | tobol
# Processing Record 28 of the Set 9 | san luis
# Processing Record 29 of the Set 9 | alyangula
# Processing Record 30 of the Set 9 | tonantins
# Processing Record 31 of the Set 9 | zaoyang
# Processing Record 32 of the Set 9 | eyl
# City not found. Skipping...
# Processing Record 33 of the Set 9 | belmonte
# Processing Record 34 of the Set 9 | saint-denis
# Processing Record 35 of the Set 9 | tremedal
# Processing Record 36 of the Set 9 | darnah
# Processing Record 37 of the Set 9 | waterloo
# Processing Record 38 of the Set 9 | nao-me-toque
# Processing Record 39 of the Set 9 | saint-francois
# Processing Record 40 of the Set 9 | mucuri
# Processing Record 41 of the Set 9 | sembe
# Processing Record 42 of the Set 9 | verkhnyaya inta
# Processing Record 43 of the Set 9 | kuusamo
# Processing Record 44 of the Set 9 | vostok
# Processing Record 45 of the Set 9 | padang
# Processing Record 46 of the Set 9 | gaziantep
# Processing Record 47 of the Set 9 | cape canaveral
# Processing Record 48 of the Set 9 | yingzhong
# Processing Record 49 of the Set 9 | ostrovnoy
# Processing Record 50 of the Set 9 | yellandu
# Processing Record 1 of the Set 10 | bakchar
# Processing Record 2 of the Set 10 | chernyshevskiy
# Processing Record 3 of the Set 10 | santo antonio do ica
# Processing Record 4 of the Set 10 | cartagena del chaira
# Processing Record 5 of the Set 10 | bozoum
# Processing Record 6 of the Set 10 | kamenskoye
# Processing Record 7 of the Set 10 | san carlos de bariloche
# Processing Record 8 of the Set 10 | ozgon
# City not found. Skipping...
# Processing Record 9 of the Set 10 | lolua
# City not found. Skipping...
# Processing Record 10 of the Set 10 | yulara
# Processing Record 11 of the Set 10 | princeton
# Processing Record 12 of the Set 10 | korla
# Processing Record 13 of the Set 10 | kabare
# Processing Record 14 of the Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 15 of the Set 10 | fortuna
# Processing Record 16 of the Set 10 | roma
# Processing Record 17 of the Set 10 | kenai
# Processing Record 18 of the Set 10 | vao
# Processing Record 19 of the Set 10 | bathsheba
# Processing Record 20 of the Set 10 | hengshui
# Processing Record 21 of the Set 10 | emet
# Processing Record 22 of the Set 10 | agadez
# Processing Record 23 of the Set 10 | srednekolymsk
# Processing Record 24 of the Set 10 | comodoro rivadavia
# Processing Record 25 of the Set 10 | boa vista
# Processing Record 26 of the Set 10 | hualmay
# Processing Record 27 of the Set 10 | ngukurr
# Processing Record 28 of the Set 10 | kaduqli
# Processing Record 29 of the Set 10 | itarema
# Processing Record 30 of the Set 10 | porto novo
# Processing Record 31 of the Set 10 | kazalinsk
# Processing Record 32 of the Set 10 | adrar
# Processing Record 33 of the Set 10 | correderos
# Processing Record 34 of the Set 10 | port-gentil
# Processing Record 35 of the Set 10 | mrirt
# Processing Record 36 of the Set 10 | pangody
# Processing Record 37 of the Set 10 | fez
# Processing Record 38 of the Set 10 | takoradi
# Processing Record 39 of the Set 10 | kalia
# Processing Record 40 of the Set 10 | key biscayne
# Processing Record 41 of the Set 10 | loandjili
# Processing Record 42 of the Set 10 | suntar
# Processing Record 43 of the Set 10 | otane
# Processing Record 44 of the Set 10 | timizart
# Processing Record 45 of the Set 10 | dibaya
# Processing Record 46 of the Set 10 | anadyr
# Processing Record 47 of the Set 10 | kaukauna
# Processing Record 48 of the Set 10 | mount isa
# Processing Record 49 of the Set 10 | sioux lookout
# Processing Record 50 of the Set 10 | coffs harbour
# Processing Record 1 of the Set 11 | at-bashi
# City not found. Skipping...
# Processing Record 2 of the Set 11 | ginir
# Processing Record 3 of the Set 11 | malabo
# Processing Record 4 of the Set 11 | coihueco
# Processing Record 5 of the Set 11 | tabuk
# Processing Record 6 of the Set 11 | algiers
# Processing Record 7 of the Set 11 | kuche
# Processing Record 8 of the Set 11 | anlu
# Processing Record 9 of the Set 11 | myaundzha
# Processing Record 10 of the Set 11 | dzhusaly
# Processing Record 11 of the Set 11 | esso
# Processing Record 12 of the Set 11 | leningradskiy
# Processing Record 13 of the Set 11 | romanovka
# Processing Record 14 of the Set 11 | marmato
# Processing Record 15 of the Set 11 | kudahuvadhoo
# Processing Record 16 of the Set 11 | tabou
# Processing Record 17 of the Set 11 | nchelenge
# Processing Record 18 of the Set 11 | marcona
# Processing Record 19 of the Set 11 | bara
# Processing Record 20 of the Set 11 | basoko
# Processing Record 21 of the Set 11 | susanville
# Processing Record 22 of the Set 11 | olafsvik
# Processing Record 23 of the Set 11 | hede
# Processing Record 24 of the Set 11 | gulshat
# Processing Record 25 of the Set 11 | tikhvin
# Processing Record 26 of the Set 11 | beecher
# Processing Record 27 of the Set 11 | monroe
# Processing Record 28 of the Set 11 | camacha
# Processing Record 29 of the Set 11 | buala
# Processing Record 30 of the Set 11 | kamenskiy
# Processing Record 31 of the Set 11 | mezen
# Processing Record 32 of the Set 11 | kiunga
# Processing Record 33 of the Set 11 | plouzane
# Processing Record 34 of the Set 11 | lidkoping
# Processing Record 35 of the Set 11 | talara
# Processing Record 36 of the Set 11 | hlubocky
# Processing Record 37 of the Set 11 | okhotsk
# Processing Record 38 of the Set 11 | tadine
# Processing Record 39 of the Set 11 | clyde
# Processing Record 40 of the Set 11 | ondorhaan
# Processing Record 41 of the Set 11 | general pico
# Processing Record 42 of the Set 11 | nantai
# Processing Record 43 of the Set 11 | gangotri
# Processing Record 44 of the Set 11 | road town
# Processing Record 45 of the Set 11 | semporna
# Processing Record 46 of the Set 11 | weligama
# Processing Record 47 of the Set 11 | roberval
# Processing Record 48 of the Set 11 | morro bay
# Processing Record 49 of the Set 11 | staryy nadym
# Processing Record 50 of the Set 11 | maragogi
# Processing Record 1 of the Set 12 | la ronge
# Processing Record 2 of the Set 12 | bernal
# Processing Record 3 of the Set 12 | niono
# Processing Record 4 of the Set 12 | the valley
# Processing Record 5 of the Set 12 | klaksvik
# Processing Record 6 of the Set 12 | sicuani
# Processing Record 7 of the Set 12 | grafton
# Processing Record 8 of the Set 12 | tautira
# Processing Record 9 of the Set 12 | kargil
# Processing Record 10 of the Set 12 | bubaque
# Processing Record 11 of the Set 12 | barda
# Processing Record 12 of the Set 12 | auburn
# Processing Record 13 of the Set 12 | inhambane
# Processing Record 14 of the Set 12 | verkhnevilyuysk
# Processing Record 15 of the Set 12 | ixtapa
# Processing Record 16 of the Set 12 | dalvik
# Processing Record 17 of the Set 12 | tongchuan
# Processing Record 18 of the Set 12 | prado
# Processing Record 19 of the Set 12 | shirgaon
# Processing Record 20 of the Set 12 | egvekinot
# Processing Record 21 of the Set 12 | vestbygda
# Processing Record 22 of the Set 12 | luderitz
# Processing Record 23 of the Set 12 | kurilsk
# Processing Record 24 of the Set 12 | ustrzyki dolne
# Processing Record 25 of the Set 12 | shushenskoye
# Processing Record 26 of the Set 12 | sundumbili
# Processing Record 27 of the Set 12 | quelimane
# Processing Record 28 of the Set 12 | wembley
# Processing Record 29 of the Set 12 | botou
# Processing Record 30 of the Set 12 | sambava
# Processing Record 31 of the Set 12 | richards bay
# Processing Record 32 of the Set 12 | casablanca
# Processing Record 33 of the Set 12 | farafangana
# Processing Record 34 of the Set 12 | kentau
# Processing Record 35 of the Set 12 | tumpat
# Processing Record 36 of the Set 12 | hamilton
# Processing Record 37 of the Set 12 | saanen
# Processing Record 38 of the Set 12 | dauphin
# Processing Record 39 of the Set 12 | bud
# Processing Record 40 of the Set 12 | ewa beach
# Processing Record 41 of the Set 12 | saint anthony
# Processing Record 42 of the Set 12 | goya
# Processing Record 43 of the Set 12 | aylmer
# Processing Record 44 of the Set 12 | laguna
# Processing Record 45 of the Set 12 | kenora
# Processing Record 46 of the Set 12 | tiarei
# Processing Record 47 of the Set 12 | marand
# Processing Record 48 of the Set 12 | las vegas
# Processing Record 49 of the Set 12 | santa cruz
# Processing Record 50 of the Set 12 | mahibadhoo
# Processing Record 1 of the Set 13 | havre-saint-pierre
# Processing Record 2 of the Set 13 | iquique
# Processing Record 3 of the Set 13 | noyabrsk
# Processing Record 4 of the Set 13 | portland
# Processing Record 5 of the Set 13 | wuwei
# Processing Record 6 of the Set 13 | nueva rosita
# Processing Record 7 of the Set 13 | kuching
# Processing Record 8 of the Set 13 | mitsamiouli
# Processing Record 9 of the Set 13 | birjand
# Processing Record 10 of the Set 13 | rozhyshche
# Processing Record 11 of the Set 13 | biskamzha
# Processing Record 12 of the Set 13 | kaduna
# Processing Record 13 of the Set 13 | te anau
# Processing Record 14 of the Set 13 | saryshagan
# Processing Record 15 of the Set 13 | marsa matruh
# Processing Record 16 of the Set 13 | xifeng
# Processing Record 17 of the Set 13 | klyuchi
# Processing Record 18 of the Set 13 | saint-leu
# Processing Record 19 of the Set 13 | porto belo
# Processing Record 20 of the Set 13 | roebourne
# Processing Record 21 of the Set 13 | chukhloma
# Processing Record 22 of the Set 13 | homestead
# Processing Record 23 of the Set 13 | malkangiri
# Processing Record 24 of the Set 13 | pleszew
# Processing Record 25 of the Set 13 | batagay
# Processing Record 26 of the Set 13 | iqaluit
# Processing Record 27 of the Set 13 | sitka
# Processing Record 28 of the Set 13 | ojinaga
# Processing Record 29 of the Set 13 | shirochanka
# Processing Record 30 of the Set 13 | coron
# Processing Record 31 of the Set 13 | gladstone
# Processing Record 32 of the Set 13 | sola
# Processing Record 33 of the Set 13 | bonthe
# Processing Record 34 of the Set 13 | orikum
# Processing Record 35 of the Set 13 | itamaraca
# Processing Record 36 of the Set 13 | manadhoo
# Processing Record 37 of the Set 13 | kamenka
# Processing Record 38 of the Set 13 | oparino
# Processing Record 39 of the Set 13 | liman
# Processing Record 40 of the Set 13 | pedro juan caballero
# Processing Record 41 of the Set 13 | bowmore
# Processing Record 42 of the Set 13 | nemuro
# Processing Record 43 of the Set 13 | bismarck
# Processing Record 44 of the Set 13 | arenapolis
# Processing Record 45 of the Set 13 | yuancheng
# Processing Record 46 of the Set 13 | atar
# Processing Record 47 of the Set 13 | guerrero negro
# Processing Record 48 of the Set 13 | grez-doiceau
# Processing Record 49 of the Set 13 | tarata
# Processing Record 50 of the Set 13 | ibra
# Processing Record 1 of the Set 14 | cuamba
# Processing Record 2 of the Set 14 | zhanaozen
# Processing Record 3 of the Set 14 | amahai
# Processing Record 4 of the Set 14 | marasesti
# Processing Record 5 of the Set 14 | grand gaube
# Processing Record 6 of the Set 14 | launceston
# Processing Record 7 of the Set 14 | alaverdi
# Processing Record 8 of the Set 14 | williams lake
# Processing Record 9 of the Set 14 | tiffin
# Processing Record 10 of the Set 14 | hachinohe
# Processing Record 11 of the Set 14 | tabiauea
# Processing Record 12 of the Set 14 | kyzyl-suu
# Processing Record 13 of the Set 14 | erdenet
# Processing Record 14 of the Set 14 | adre
# Processing Record 15 of the Set 14 | isangel
# Processing Record 16 of the Set 14 | lakes entrance
# Processing Record 17 of the Set 14 | tulum
# Processing Record 18 of the Set 14 | bundaberg
# Processing Record 19 of the Set 14 | ebersbach
# Processing Record 20 of the Set 14 | ilo
# Processing Record 21 of the Set 14 | verkhnyaya toyma
# Processing Record 22 of the Set 14 | san pedro
# Processing Record 23 of the Set 14 | abnub
# Processing Record 24 of the Set 14 | linguere
# Processing Record 25 of the Set 14 | yining
# Processing Record 26 of the Set 14 | huaiyin
# Processing Record 27 of the Set 14 | kantunilkin
# Processing Record 28 of the Set 14 | nelspruit
# Processing Record 29 of the Set 14 | labuan
# Processing Record 30 of the Set 14 | yarada
# Processing Record 31 of the Set 14 | bajo baudo
# Processing Record 32 of the Set 14 | okha
# Processing Record 33 of the Set 14 | puro
# Processing Record 34 of the Set 14 | tubruq
# Processing Record 35 of the Set 14 | peruibe
# Processing Record 36 of the Set 14 | nuuk
# Processing Record 37 of the Set 14 | robe
# Processing Record 38 of the Set 14 | tuggurt
# Processing Record 39 of the Set 14 | wanning
# Processing Record 40 of the Set 14 | gobabis
# Processing Record 41 of the Set 14 | belaya gora
# Processing Record 42 of the Set 14 | beya
# Processing Record 43 of the Set 14 | ponta do sol
# Processing Record 44 of the Set 14 | cruz alta
# Processing Record 45 of the Set 14 | kachiry
# Processing Record 46 of the Set 14 | fatehpur
# Processing Record 47 of the Set 14 | manitouwadge
# Processing Record 48 of the Set 14 | huarmey
# Processing Record 49 of the Set 14 | maraba
# Processing Record 50 of the Set 14 | eirunepe
# Processing Record 1 of the Set 15 | gela
# Processing Record 2 of the Set 15 | fairbanks
# Processing Record 3 of the Set 15 | xique-xique
# Processing Record 4 of the Set 15 | kuah
# Processing Record 5 of the Set 15 | rivers
# Processing Record 6 of the Set 15 | havoysund
# Processing Record 7 of the Set 15 | amurrio
# Processing Record 8 of the Set 15 | aviles
# Processing Record 9 of the Set 15 | bandarbeyla
# Processing Record 10 of the Set 15 | malakal
# Processing Record 11 of the Set 15 | samarai
# Processing Record 12 of the Set 15 | kieta
# Processing Record 13 of the Set 15 | vestmannaeyjar
# Processing Record 14 of the Set 15 | arona
# Processing Record 15 of the Set 15 | vicosa
# Processing Record 16 of the Set 15 | sinkat
# Processing Record 17 of the Set 15 | juneau
# Processing Record 18 of the Set 15 | zhezkazgan
# Processing Record 19 of the Set 15 | wajima
# Processing Record 20 of the Set 15 | tuscaloosa
# Processing Record 21 of the Set 15 | talcher
# Processing Record 22 of the Set 15 | slave lake
# Processing Record 23 of the Set 15 | sao gabriel da cachoeira
# Processing Record 24 of the Set 15 | kampot
# Processing Record 25 of the Set 15 | shimoda
# Processing Record 26 of the Set 15 | borovoy
# Processing Record 27 of the Set 15 | kuznechikha
# Processing Record 28 of the Set 15 | krems
# Processing Record 29 of the Set 15 | sadovoye
# Processing Record 30 of the Set 15 | butembo
# Processing Record 31 of the Set 15 | lethem
# Processing Record 32 of the Set 15 | chumikan
# Processing Record 33 of the Set 15 | santa cruz
# Processing Record 34 of the Set 15 | bonavista
# Processing Record 35 of the Set 15 | northam
# Processing Record 36 of the Set 15 | nueve de julio
# Processing Record 37 of the Set 15 | irati
# Processing Record 38 of the Set 15 | obodivka
# Processing Record 39 of the Set 15 | newton
# Processing Record 40 of the Set 15 | cagayan de tawi-tawi
# Processing Record 41 of the Set 15 | hibbing
# Processing Record 42 of the Set 15 | biak
# Processing Record 43 of the Set 15 | venezuela
# Processing Record 44 of the Set 15 | comacchio
# Processing Record 45 of the Set 15 | zarya
# Processing Record 46 of the Set 15 | pandan
# Processing Record 47 of the Set 15 | trairi
# Processing Record 48 of the Set 15 | flin flon
# Processing Record 49 of the Set 15 | palmerston
# Processing Record 50 of the Set 15 | puerto colombia
# Processing Record 1 of the Set 16 | iracoubo
# Processing Record 2 of the Set 16 | north myrtle beach
# Processing Record 3 of the Set 16 | lazaro cardenas
# Processing Record 4 of the Set 16 | lieksa
# Processing Record 5 of the Set 16 | kuala kedah
# Processing Record 6 of the Set 16 | kouroussa
# Processing Record 7 of the Set 16 | yerbogachen
# Processing Record 8 of the Set 16 | olinda
# Processing Record 9 of the Set 16 | virginia beach
# Processing Record 10 of the Set 16 | alto araguaia
# Processing Record 11 of the Set 16 | quatre cocos
# Processing Record 12 of the Set 16 | palana
# Processing Record 13 of the Set 16 | nelson bay
# Processing Record 14 of the Set 16 | sao sebastiao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 699

# %%
# Add the data to a new DataFrame.
cities_weather_df = pd.DataFrame(city_data)

# Label the columns
cities_weather_df = cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Kontokalion      GR  39.6453   19.8494     66.06        82
# 1  Euclides Da Cunha      BR -10.5075  -39.0158     68.22        97
# 2        Yellowknife      CA  62.4560 -114.3525     52.32        37
# 3            Mataura      NZ -46.1927  168.8643     54.48        91
# 4             Albany      US  42.6001  -73.9662     57.45        81
# 5      Victor Harbor      US  42.6001  -73.9662     57.45        81
# 6          Carnarvon      US  42.6001  -73.9662     57.45        81
# 7           Terlizzi      IT  41.1311   16.5453     63.14        86
# 8           Nanyamba      TZ -10.6833   39.8333     64.76        96
# 9           Meiktila      MM  20.8667   95.8667     91.98        49
#
#    Cloudiness  Wind Speed Current Description
# 0          20        0.00          few clouds
# 1         100        3.51     overcast clouds
# 2          75       11.50       broken clouds
# 3         100        0.72     overcast clouds
# 4          60        1.01       broken clouds
# 5          60        1.01       broken clouds
# 6          60        1.01       broken clouds
# 7          66        2.04       broken clouds
# 8           5        4.50           clear sky
# 9          54       14.03       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the Dataframe as a CSV file.
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
